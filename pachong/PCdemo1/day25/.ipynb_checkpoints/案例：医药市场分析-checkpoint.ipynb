# 2866    2000                           迪康16毫升/瓶/盒        迪康                空
# 2867   13000                             中智4g*10袋        中智                空
# 2868   66000                           开瑞坦10mg*6片       开瑞坦               鼻痒
# 2869   18000                           步长0.3g*24粒        步长               其它
# 2870    4900                               息斯敏10片       息斯敏               其它
# 2871    4800                       陈李济0.25g*24粒/盒       陈李济             喉咙肿痛
# 2872   20000                         开瑞坦氯雷他定口腔崩解片       开瑞坦               其它
# 2873   69000                             息斯敏氯雷他定片       息斯敏               其它
# 2874   20000                          诺通盐酸赛洛唑啉滴鼻液        诺通               其它
# 2875    4500                           逸舒氯雷他定片 6片        逸舒              打喷嚏
# 2876    8600  仙特明盐酸西替利嗪片10mg*5片/盒（季节性鼻炎,常年性过敏性鼻炎）       仙特明               其它
# 2877    2400                                希臣铁笛片        希臣             喉咙肿痛
# 2878     600                      济民可信金果饮15ml*10支      济民可信                空
# 2879    1600                               王屋山48片       王屋山          咽部灼热，其它
#
#               type
# 0             阴阳亏虚
# 1         肾阳虚，阴阳亏虚
# 2           腰椎间盘突出
# 3              肾阴亏
# 4          肾阳虚，肾阴亏
# 5              肾阴亏
# 6                空
# 7             阳痿不育
# 8             阴阳亏虚
# 9             阴阳亏虚
# 10            遗精早泄
# 11            风湿骨痛
# 12             肾阴亏
# 13             肾阴亏
# 14              其它
# 15              其它
# 16            阴阳亏虚
# 17             肾阴亏
# 18              其它
# 19               空
# 20               空
# 21             肾阳虚
# 22             肾阴亏
# 23             肾阳虚
# 24            阳痿不育
# 25               空
# 26               空
# 27              其它
# 28               空
# 29             肾阴亏
# ...            ...
# 2850        鼻炎，鼻窦炎
# 2851         急慢性咽炎
# 2852         急慢性咽炎
# 2853             空
# 2854            鼻炎
# 2855             空
# 2856             空
# 2857             空
# 2858  鼻炎，鼻窦炎，过敏性鼻炎
# 2859            鼻炎
# 2860          扁桃体炎
# 2861          耳聋耳鸣
# 2862            鼻炎
# 2863     慢性喉炎，扁桃体炎
# 2864         过敏性鼻炎
# 2865             空
# 2866  鼻炎，鼻窦炎，过敏性鼻炎
# 2867    扁桃体炎，急慢性咽炎
# 2868            鼻炎
# 2869        鼻炎，鼻窦炎
# 2870             空
# 2871          扁桃体炎
# 2872         过敏性鼻炎
# 2873         过敏性鼻炎
# 2874        鼻炎，鼻窦炎
# 2875            鼻炎
# 2876      鼻炎，过敏性鼻炎
# 2877            其它
# 2878             空
# 2879         急慢性咽炎
#
# [2880 rows x 8 columns]

# %% [markdown]
# # 数据清洗

# %% [markdown]
# ### 查看数据信息

# %%
df_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 8 columns):
# category    2880 non-null object
# title       2880 non-null object
# price       2880 non-null float64
# nums        2880 non-null int64
# name        2880 non-null object
# brand       2880 non-null object
# symptoms    2880 non-null object
# type        2880 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 180.1+ KB

# %% [markdown]
# ### 查看原始数据维度大小

# %%
print(df_obj.shape)
# Out:
# (2880, 8)

# %% [markdown]
# ### 查看销量为0的药品

# %%
print(df_obj[df_obj['nums']==0])
# Out:
#      category                     title  price  nums  \
# 2390     儿科用药  伊可新 维生素AD滴剂(1岁以上)胶囊型 30粒   40.7     0
# 2450     儿科用药  伊可新 维生素AD滴剂(1岁以上)胶囊型 30粒   40.7     0
# 2510     儿科用药  伊可新 维生素AD滴剂(1岁以上)胶囊型 30粒   40.7     0
#
#                           name brand     symptoms  type
# 2390  伊可新 维生素AD滴剂(1岁以上)胶囊型 30粒   伊可新  抽搐症，夜盲症，佝偻症  小儿维矿
# 2450  伊可新 维生素AD滴剂(1岁以上)胶囊型 30粒   伊可新  抽搐症，夜盲症，佝偻症  小儿维矿
# 2510  伊可新 维生素AD滴剂(1岁以上)胶囊型 30粒   伊可新  抽搐症，夜盲症，佝偻症  小儿维矿

# %% [markdown]
# ### 过滤销量为0的药品

# %%
df_obj = df_obj[df_obj['nums']>0]
print(df_obj)
# Out:
#      category                                              title   price  \
# 0        补肾壮阳                汇仁 肾宝片 126片 调和阴阳温阳补肾扶正固本 男女同补补肾中成药品   322.0
# 1        补肾壮阳                汇仁 肾宝片 126片 肾虚肾亏补肾中药肾气丸滋阴壮阳 推荐2盒1疗程   322.0
# 2       风湿骨外伤           白云山 陈李济 舒筋健腰丸45g*10瓶 补益肝肾 强健筋骨 驱风除湿 活络止痛   890.0
# 3        补肾壮阳            同仁堂 六味地黄丸（浓缩丸）300丸 （男女肾虚肾亏中药品滋阴补肾）六味地黄丸    49.5
# 4        补肾壮阳                汇仁 肾宝片礼盒装 126片*4盒礼盒装温阳补肾肾虚肾亏京东自营旗舰店  1188.0
# 5        补肾壮阳             九芝堂 六味地黄丸（浓缩丸）618丸 滋阴补肾腰膝酸软遗精男女药六位滋补药品    49.9
# 6        补肾壮阳                   成博士 参花消渴茶 60袋 滋阴补肾 益气生津 适用于Ⅱ型糖尿病   495.0
# 7        补肾壮阳        同仁堂 五子衍宗丸 60g/瓶 肾虚精亏所致的阳痿不育遗精早泄腰痛尿后余沥 北京同仁堂    26.0
# 8        补肾壮阳     【大包装，更优惠】汇仁 肾宝片 126片*4盒 调和阴阳 温阳补肾 高端木质礼盒装 2个疗程  1188.0
# 9        补肾壮阳                    【试用装】汇仁 肾宝片 45片 肾虚肾亏补肾中药肾气丸滋阴壮阳   125.0
# 10       补肾壮阳                同仁堂 锁阳固精丸 9克*10丸 补肾固精腰膝酸软遗精早泄 北京同仁堂    28.0
# 11      风湿骨外伤      葛洪 桂龙药膏202g*6瓶 祛风除湿舒筋活络温肾补血用于风湿骨痛 慢性腰腿痛 6瓶礼盒装  1290.0
# 12       补肾壮阳           九芝堂 六味地黄丸（浓缩丸）360丸 滋阴补肾 腰膝酸软遗精 男女滋补药六位药品    32.8
# 13       补肾壮阳  仲景 六味地黄丸(浓缩丸)360丸*2瓶/盒 中药滋阴补肾虚亏壮阳腰膝酸软男女六位药 推荐3...    58.0
# 14       补肾壮阳        济民可信金水宝胶囊72粒 治疗阳痿早泄肾虚 补益肺肾 腰膝痠软 中药 虫草菌粉CS-4    58.0
# 2874        鼻炎，鼻窦炎
# 2875            鼻炎
# 2876      鼻炎，过敏性鼻炎
# 2877            其它
# 2878             空
# 2879         急慢性咽炎
#
# [2877 rows x 8 columns]

# %%
print(df_obj.shape)
# Out:
# (2877, 8)

# %% [markdown]
# # 数据分析

# %% [markdown]
# ### 统计不同类别药品的数量

# %%
ser_size = df_obj.groupby('category').size()
print(ser_size)
# Out:
# category
# 儿科用药     269
# 妇科用药     190
# 心脑血管      10
# 感冒咳嗽     301
# 止痛镇痛      42
# 皮肤用药     425
# 维矿物质     236
# 耳鼻喉用药    187
# 肠胃消化     406
# 补气养血     260
# 补肾壮阳     309
# 风湿骨外伤    242
# dtype: int64

# %%
# 设置画布的尺寸
plt.figure(figsize=(16,9)) 
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 避免中文乱码
fig,ax = plt.subplots(1)
ax.set_title('不同类别下药品数量统计') # 设置标题
ax.pie(ser_size,labels=ser_size.index,autopct='%3.1f%%',labeldistance=1.07,shadow=True,radius=1)
plt.legend(loc=1,bbox_to_anchor=(1.4,1.1))  # 显示图例
plt.axis('tight') # 显示为椭圆
plt.savefig('./images/img_1.jpg') # 图片保存
plt.show()

# %% [markdown]
# ### 统计不同类别药品最高价格和最低价格

# %%
ser_max_price = df_obj.groupby('category').max()['price']
ser_min_price = df_obj.groupby('category').min()['price']
print(ser_max_price)
print(ser_min_price)
# Out:
# category
# 儿科用药      298.0
# 妇科用药      387.0
# 心脑血管      790.0
# 感冒咳嗽      298.0
# 止痛镇痛       30.2
# 皮肤用药      398.0
# 维矿物质      285.0
# 耳鼻喉用药      75.0
# 肠胃消化      327.0
# 补气养血     2198.0
# 补肾壮阳     1380.0
# 风湿骨外伤    1290.0
# Name: price, dtype: float64
# category
# 儿科用药       9.9
# 妇科用药       7.9
# 心脑血管     585.0
# 感冒咳嗽       9.6
# 止痛镇痛       8.9
# 皮肤用药      10.0
# 维矿物质       5.8
# 耳鼻喉用药      3.9
# 肠胃消化       9.9
# 补气养血      18.0
# 补肾壮阳      12.8
# 风湿骨外伤      5.0
# Name: price, dtype: float64

# %%
fig,ax = plt.subplots(1)
# 横坐标
x = np.arange(len(ser_max_price))
# 柱形宽度
width = 0.65
ax.bar(x,ser_max_price,width,label='最高价')
ax.bar(x,ser_min_price,width,label='最低价')
# 标题
ax.set_title('不同类别下药品最高价格和最低价格')
ax.set_xlabel('药品类别') # 水平轴的标签
ax.set_ylabel('价格') # 垂直轴的标签
# 水平轴上刻度显示的位置
ax.set_xticks(x) # 设置x轴刻度显示位置
ax.set_xticklabels(ser_max_price.index,rotation=45)  # 设置水平轴刻度标签
ax.set_yticks(np.arange(0,3000,500)) # 设置y轴刻度位置
ax.legend(loc='best') # 显示图例
plt.savefig('./images/img_2.png') # 存储图片
plt.show()

# %% [markdown]
# ### 不同类别药品价格分布

# %%
# 按照类别对价格进行分组
df_group = df_obj.groupby('category')['price']
colors = ['#ff1122','#ee88ff','#dd3366','#ccaa11','#aa55aa','#996633','#886655','#775577','#664499','#553311','#3366ff','#447722']
labels = list(ser_max_price.index)
print(labels)
fig,ax = plt.subplots(1)
# 设置标题
ax.set_title('不同类别药品价格分布')
i = 0
for name,value in df_group:
    print(name)
    label = labels[i]
    color = colors[i]
    x = np.ones(len(value)) * (i+1)
    ax.scatter(x,value,color=color,label=label,marker='o')
    i+=1
# 设置刻度显示位置
ax.set_xticks(np.arange(len(labels)))
# 设置刻度标签
ax.set_xticklabels(labels,rotation=45)
ax.legend(loc = 1,bbox_to_anchor=(1.4,1.1)) # 显示图例
plt.savefig('./images/img_3.jpg') # 保存图片
plt.show()
# Out:
# ['儿科用药', '妇科用药', '心脑血管', '感冒咳嗽', '止痛镇痛', '皮肤用药', '维矿物质', '耳鼻喉用药', '肠胃消化', '补气养血', '补肾壮阳', '风湿骨外伤']
# 儿科用药
# 妇科用药
# 心脑血管
# 感冒咳嗽
# 止痛镇痛
# 皮肤用药
# 维矿物质
# 耳鼻喉用药
# 肠胃消化
# 补气养血
# 补肾壮阳
# 风湿骨外伤

# %%
### 统计不同类别价格分布区间

# %%
fig,subplot_arr = plt.subplots(3,4,figsize=(18,12))
grouped = df_obj.groupby('category')
c = 0
for name,value in grouped:
    i = c//4
    j = c%4
    subplot_arr[i,j].set_title(name+'价格分布')
    subplot_arr[i,j].hist(df_obj[df_obj['category']==name]['price'],bins=22)
    c+=1
plt.savefig('./images/img_4.jpg')
plt.show()

# %% [markdown]
# ### 各个类别下销量最佳的药品分析

# %%
ser_max_nums = df_obj.groupby('category').max()
print(ser_max_nums[['name','nums']])
# Out:
#                       name    nums
# category
# 儿科用药              龙牡龙牡壮骨颗粒  510000
# 妇科用药                金鸡金鸡胶囊  190000
# 心脑血管               天草丹参保心茶   51000
# 感冒咳嗽          香雪橘红痰咳液（无糖型）  850000
# 止痛镇痛                芬必得24粒  170000
# 皮肤用药             采乐2%*50ml  320000
# 维矿物质      钙尔奇碳酸钙维D3元素片100片  650000
# 耳鼻喉用药        雷诺考特32ug*120喷  250000
# 肠胃消化              马应龙麝香痔疮膏  620000
# 补气养血       青春宝抗衰老片80片*6瓶简装  280000
# 补肾壮阳        阿房宫虫草双参酒 500ml  840000
# 风湿骨外伤             颈复康颈复康颗粒  150000

# %%
fig,ax = plt.subplots(1)
ax.set_title('各个类别销量最佳药品分析')
bar_height = 0.6
y = list(ser_max_nums['name'])
ax.barh(y=np.arange(len(y)),width=ser_max_nums['nums'],height=bar_height,color='indianred',alpha=0.8)
# 在柱形图上显示具体数值，
for ypos,x in enumerate(ser_max_nums['nums']):
    ax.text(x+5000,ypos-bar_height/2,'%s'%x,ha='left',va='bottom')
ax.set_xlabel('销量（件）')
ax.set_ylabel('药品名称')
# 设置y轴刻度
ax.set_yticks(np.arange(len(y)))
ax.set_yticklabels(y)
plt.savefig('./images/img_5.jpg')
plt.show()

# %% [markdown]
# ### 各个类别销售额最佳的药品分析

# %%
df_obj['amount'] = df_obj['price'] * df_obj['nums']
print(df_obj.iloc[1,:])
# Out:
# category                                   补肾壮阳
# title       汇仁 肾宝片 126片 肾虚肾亏补肾中药肾气丸滋阴壮阳 推荐2盒1疗程
# price                                       322
# nums                                     400000
# name                                汇仁0.7g*126片
# brand                                        汇仁
# symptoms                                   畏寒怕冷
# type                                   肾阳虚，阴阳亏虚
# amount                                1.288e+08
# Name: 1, dtype: object

# %%
df_max_amount = df_obj.groupby('category').max()
print(df_max_amount['name'],df_max_amount['amount'])
# Out:
# category
# 儿科用药             龙牡龙牡壮骨颗粒
# 妇科用药               金鸡金鸡胶囊
# 心脑血管              天草丹参保心茶
# 感冒咳嗽         香雪橘红痰咳液（无糖型）
# 止痛镇痛               芬必得24粒
# 皮肤用药            采乐2%*50ml
# 维矿物质     钙尔奇碳酸钙维D3元素片100片
# 耳鼻喉用药       雷诺考特32ug*120喷
# 肠胃消化             马应龙麝香痔疮膏
# 补气养血      青春宝抗衰老片80片*6瓶简装
# 补肾壮阳       阿房宫虫草双参酒 500ml
# 风湿骨外伤            颈复康颈复康颗粒
# Name: name, dtype: object category
# 儿科用药      34680000.0
# 妇科用药      27099800.0
# 心脑血管      40290000.0
# 感冒咳嗽      22720000.0
# 止痛镇痛       5134000.0
# 皮肤用药      33540000.0
# 维矿物质     185250000.0
# 耳鼻喉用药     18750000.0
# 肠胃消化     104640000.0
# 补气养血     615440000.0
# 补肾壮阳     155480000.0
# 风湿骨外伤     50730000.0
# Name: amount, dtype: float64

# %%
fig,ax= plt.subplots(1)
ax.set_title('各个类别销售额最佳药品分析')
bar_height =0.6
y = list(df_max_amount['name'])
ax.barh(y=np.arange(len(y)),width=df_max_amount['amount'],height=bar_height,color='indianred',alpha=0.8)
for ypos,x in enumerate(df_max_amount['amount']):
    ax.text(x+5000,ypos-bar_height/2,'%s'%x,ha='left',va='bottom')
ax.set_xlabel('销售额(元)')
ax.set_ylabel('药品名称')
ax.set_yticks(np.arange(len(y)))
ax.set_yticklabels(y)
plt.savefig('./images/img_6.jpg')
plt.show()

# %% [markdown]
# ### 不同类别药品销售额分析

# %%
ser_amount = df_obj.groupby('category')['amount'].sum()
print(ser_amount)
fig,ax = plt.subplots(1)
ax.set_title('不同类别销售额分析')
ax.pie(ser_amount,labels=ser_amount.index,autopct='%3.1f%%',labeldistance=1.07,shadow=True,radius=1)
plt.legend(loc=1,bbox_to_anchor=(1.43,1.1))
plt.axis('tight')
plt.savefig('./images/img_7.jpg')
plt.show()
# Out:
# category
# 儿科用药     7.717087e+08
# 妇科用药     4.884206e+08
# 心脑血管     2.541000e+08
# 感冒咳嗽     1.888677e+09
# 止痛镇痛     1.051134e+08
# 皮肤用药     1.977697e+09
# 维矿物质     6.195001e+09
# 耳鼻喉用药    3.511291e+08
# 肠胃消化     3.883154e+09
# 补气养血     9.227458e+09
# 补肾壮阳     5.234041e+09
# 风湿骨外伤    1.327018e+09
# Name: amount, dtype: float64

# %% [markdown]
# ### 品牌药品销售额分析

# %%
df_amount_by_brand = df_obj.groupby('brand').sum()
print(df_amount_by_brand)
# Out:
#                        price      nums        amount
# brand
# 21金维他                1747.20   5600000  4.892160e+08
# 999                  3086.65  39933000  8.349385e+08
# BMI                   700.00      4200  4.200000e+05
# MOL                   108.00     24300  8.748000e+05
# 丁桂                    681.00   2040000  1.157700e+08
# 万特力                  1714.60   1196000  7.887160e+07
# 万通                    131.00    132000  2.676000e+06
# 三公仔                   198.00    600000  1.188000e+07
# 三康                    143.60    112000  4.020800e+06
# 三精                     84.00      2800  5.880000e+04
# 三金                     56.10    456000  4.342800e+06
# 东信                     36.00     54000  6.480000e+05
# 东北制药                   98.00     84000  1.176000e+06
# 东阿阿胶                31250.00  11249500  7.111936e+09
# 中新                    114.00     45000  1.710000e+06
# 中智                     15.60     39000  2.028000e+05
# 丹南泰                  1372.00    252000  2.469600e+07
# 丽芙                    126.00    532000  9.576000e+06
# 乐家老铺                 3480.00    225000  5.220000e+07
# 九芝堂                 10700.10  13484000  1.207311e+09
# 云丰                    280.00    355600  6.563200e+06
# 云南白药（YUNNANBAIYAO）   6517.70   8029800  3.329010e+08
# 京万红                   139.30    196000  3.900400e+06
# 京果                    310.00    135000  8.370000e+06
# 京都念慈菴                 634.20   5600000  2.536800e+08
# 亮甲                   1263.30   2240000  2.021280e+08
# 仁和                   1430.50   1649500  3.917585e+07
# 仁和可立克（RH）             159.60    259000  5.905200e+06
# 仙特明                    56.40     25800  4.850400e+05
# 以岭（YILING）           2150.84   1291500  2.597644e+07
# ...                      ...       ...           ...
# 达喜                    420.00   1540000  4.620000e+07
# 达林                    133.00     98000  1.862000e+06
# 达芬霖                    59.70     33000  6.567000e+05
# 达霏欣                  2352.00   1008000  1.693440e+08
# 还尔金                   260.00     32000  1.664000e+06
# 迪巧                   2829.20  15400000  1.556060e+09
# 迪康                    190.80     78000  1.700700e+06
# 迪赛诺                   333.90   2100000  5.008500e+07
# 速力菲                   124.50    100000  2.490000e+06
# 速笑                    126.00    147000  2.646000e+06
# 逸舒                     11.70     13500  5.265000e+04
# 邦廸（BAND-AID）          139.30    504000  1.002960e+07
# 邦琪药业                   63.00      9300  1.953000e+05
# 采乐                    224.00   1120000  3.584000e+07
# 金丐                    332.00    144000  5.976000e+06
# 金嗓子                   107.70    576000  1.033920e+07
# 金方                     75.00     22800  5.700000e+05
# 金施尔康                  396.00    100000  9.900000e+06
# 金鸡                   1596.60   1092000  1.452906e+08
# 钙尔奇（Caltrate）        2388.00  15120000  1.289520e+09
# 阿房宫                  2475.00      8500  4.207500e+06
# 陈李济                  8279.00    667400  4.612660e+08
# 雅塑（yasu）             2779.00   1330000  2.640050e+08
# 雷允上                   690.00     17000  2.346000e+06
# 雷诺考特                  421.50    600000  4.215000e+07
# 青春宝                  1740.00     20000  6.960000e+06
# 颈复康                   291.20    208000  7.571200e+06
# 香雪                    924.00   1680000  7.392000e+07
# 马应龙                   726.60  21700000  4.504920e+08
# 龙牡                    609.00    554200  2.500260e+07
#
# [223 rows x 3 columns]

# %%
# 降序排序
df_amount_by_brand = df_amount_by_brand.sort_values(by='amount',ascending=False)
df_amount_by_brand = df_amount_by_brand[df_amount_by_brand['amount']>=100000000]
print(df_amount_by_brand)
# Out:
#                        price      nums        amount
# brand
# 东阿阿胶                31250.00  11249500  7.111936e+09
# 同仁堂（TRT）            23277.50  47815100  2.302364e+09
# 汇仁                  25014.70   8999500  2.137433e+09
# 爱乐维（Menevit）         3648.00  10408400  1.961727e+09
# 迪巧                   2829.20  15400000  1.556060e+09
# 舒尔佳                  4532.50   8960000  1.450400e+09
# 钙尔奇（Caltrate）        2388.00  15120000  1.289520e+09
# 九芝堂                 10700.10  13484000  1.207311e+09
# 999                  3086.65  39933000  8.349385e+08
# 盘龙云海                 3402.00   4410000  7.144200e+08
# 敖东                   2665.00   5250000  5.596500e+08
# 21金维他                1747.20   5600000  4.892160e+08
# 慢严舒柠（MINT）           1917.30   8750000  4.793250e+08
# 蔓迪                   1778.00   3640000  4.622800e+08
# 陈李济                  8279.00    667400  4.612660e+08
# 马应龙                   726.60  21700000  4.504920e+08
# 福胶                   9530.00    675000  4.288500e+08
# 达克宁                  2131.50  12627900  3.488720e+08
# 云南白药（YUNNANBAIYAO）   6517.70   8029800  3.329010e+08
# 伊可新                   646.80   6120000  3.298680e+08
# 奇正                   3179.60   2700000  3.179600e+08
# 济民可信                 3955.50   2150800  2.934308e+08
# 葛洪                  26889.00    320000  2.817330e+08
# 雅塑（yasu）             2779.00   1330000  2.640050e+08
# 善存（Centrum）          1088.00   2880000  2.611200e+08
# 星鲨                    868.50   6233000  2.571255e+08
# 京都念慈菴                 634.20   5600000  2.536800e+08
# 艾丽                   3419.50   2101400  2.214142e+08
# 仲景                   2174.60   6282800  2.099920e+08
# 白云山                  1495.40   9493600  2.096655e+08
# 亮甲                   1263.30   2240000  2.021280e+08
# 同溢堂                  3950.00    255000  2.014500e+08
# 前列康                   515.00   3900000  2.008500e+08
# 辅舒良                   750.00   2500000  1.875000e+08
# 江中                    854.40   7971200  1.870118e+08
# 达霏欣                  2352.00   1008000  1.693440e+08
# 荣昌                   1029.00   4200000  1.543500e+08
# 金鸡                   1596.60   1092000  1.452906e+08
# 丁桂                    681.00   2040000  1.157700e+08
# 朗迪                   3124.00   1040000  1.110880e+08
# 养无极                  2086.00    371000  1.105580e+08

# %%
print(df_amount_by_brand.shape)
fig,ax = plt.subplots(1,figsize=(20,12))
ax.set_title('销售额过亿的品牌分析')
bar_height = 0.6
y = list(df_amount_by_brand.index)
ax.barh(y=np.arange(len(y)),width=df_amount_by_brand['amount'],height=bar_height,color='indianred',alpha=0.8)
for ypos,x in enumerate(df_amount_by_brand['amount']):
    ax.text(x+5000,ypos-bar_height/2,'%s'%x,ha='left',va='bottom')

ax.set_xlabel('销售额(元)')
ax.set_ylabel('品牌')
ax.set_yticks(np.arange(len(y)))
ax.set_yticklabels(y)
plt.savefig('./images/img_8.jpg')
plt.show()
# Out:
# (41, 3)
